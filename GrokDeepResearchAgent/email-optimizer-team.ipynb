# %%
from autogen_agentchat.teams import RoundRobinGroupChat
from autogen_agentchat.agents import AssistantAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.conditions import MaxMessageTermination, TextMentionTermination
from autogen_agentchat.ui import Console

# %%
model = OpenAIChatCompletionClient(model="gpt-4o-mini")

clarity_agent = AssistantAgent(
    "ClarityAgent",
    model_client=model,
    system_message="""You are an expert editor focused on clarity and simplicity. 
            Your job is to eliminate ambiguity, redundancy, and make every sentence crisp and clear. 
            Don't worry about persuasion or tone — just make the message easy to read and understand.""",
)

tone_agent = AssistantAgent(
    "ToneAgent",
    model_client=model,
    system_message="""You are a communication coach focused on emotional tone and professionalism. 
            Your job is to make the email sound warm, confident, and human — while staying professional 
            and appropriate for the audience. Improve the emotional resonance, polish the phrasing, 
            and adjust any words that may come off as stiff, cold, or overly casual.""",
)

persuasion_agent = AssistantAgent(
    "PersuasionAgent",
    model_client=model,
    system_message="""You are a persuasion expert trained in marketing, behavioral psychology, 
            and copywriting. Your job is to enhance the email's persuasive power: improve call to action, structure arguments, and emphasize benefits. Remove weak or passive language.""",
)

synthesizer_agent = AssistantAgent(
    "SynthesizerAgent",
    model_client=model,
    system_message="""You are an advanced email-writing specialist. Your role is to read all 
            prior agent responses and revisions, and then **synthesize the best ideas** into a unified, 
            polished draft of the email. Focus on: Integrating clarity, tone, and persuasion improvements; 
            Ensuring coherence, fluency, and a natural voice; Creating a version that feels professional, 
            effective, and readable.""",
)

critic_agent = AssistantAgent(
    "CriticAgent",
    model_client=model,
    system_message="""You are an email quality evaluator. Your job is to perform a final review 
            of the synthesized email and determine if it meets professional standards. Review the email for: 
            Clarity and flow, appropriate professional tone, effective call-to-action, and overall coherence.
            Be constructive but decisive. If the email has major flaws (unclear message, unprofessional tone, 
            or missing key elements), provide ONE specific improvement suggestion. If the email meets professional standards and communicates effectively, respond with 'The email meets professional standards.' followed by `TERMINATE` on a new line. You should only approve emails that are perfect enough for professional use, dont settle.""",
)

# %%
text_termination = TextMentionTermination("TERMINATE")
max_message_termination = MaxMessageTermination(max_messages=30)

termination_condition = text_termination | max_message_termination

team = RoundRobinGroupChat(
    participants=[
        clarity_agent, 
        tone_agent, 
        persuasion_agent, 
        synthesizer_agent, 
        critic_agent,
    ],
    termination_condition=termination_condition,
)

await Console(
    team.run_stream(task="Hi! I'm get bored, buy me a coffee and invest in my business. Thanks!")
)
# Out:
# ---------- TextMessage (user) ----------
# Hi! I'm get bored, buy me a coffee and invest in my business. Thanks!
# ---------- TextMessage (ClarityAgent) ----------
# Hi! I'm bored. Please buy me a coffee and invest in my business. Thanks!
# ---------- TextMessage (ToneAgent) ----------
# Subject: A Little Support Goes a Long Way!
#
# Hi there,
#
# I hope this message finds you well! I wanted to reach out because I find myself in a bit of a creative lull. I would truly appreciate your support by grabbing a coffee together—perhaps we can brainstorm some exciting ideas for my business.
#
# Your investment would mean the world to me and could make a significant difference in taking my vision to the next level.
#
# Thank you for considering this! Looking forward to hearing from you.
#
# Warm regards,
# [Your Name]
# ---------- TextMessage (PersuasionAgent) ----------
# Subject: Let's Brew Something Amazing Together!
#
# Hi [Recipient's Name],
#
# I hope this message finds you thriving! I’m reaching out to invite you to join me for a coffee—and in doing so, I’d love to share my vision for my business and discuss how your support can elevate it to new heights!
#
# Imagine what we could accomplish together! With just a small investment, you could be a key player in transforming my ideas into reality. Your insights and support could provide the catalyst I need to break through this creative lull and create something extraordinary.
#
# Are you available to meet this week? I can’t wait to explore how we can collaborate and bring our ideas to life!
#
# Thank you for considering this opportunity. Let’s connect soon!
#
# Best,
# [Your Name]
# [Your Contact Information]
# ---------- TextMessage (SynthesizerAgent) ----------
# Subject: Let’s Brew Something Amazing Together!
#
# Hi [Recipient's Name],
#
# I hope this message finds you thriving! I'm reaching out with a proposal that combines inspiration and collaboration. I would love to invite you for a coffee, where I can share my vision for my business and explore how your support could elevate it to new heights.
#
# With just a small investment, you could be an integral part of bringing my ideas to life. Your insights and encouragement would be invaluable, especially as I navigate through this creative lull. Together, we can brainstorm innovative strategies that could transform my business.
#
# Are you available to meet this week? I’m excited about the prospect of collaborating and would appreciate the opportunity to discuss this with you.
#
# Thank you for considering this opportunity. I look forward to hearing from you soon!
#
# Best regards,
# [Your Name]
# [Your Contact Information]
# ---------- TextMessage (CriticAgent) ----------
# The email meets professional standards.
# TERMINATE
# TaskResult(messages=[TextMessage(id='d53a5940-9769-45dd-9618-c3b0c2f17130', source='user', models_usage=None, metadata={}, created_at=datetime.datetime(2026, 1, 26, 18, 11, 19, 184473, tzinfo=datetime.timezone.utc), content="Hi! I'm get bored, buy me a coffee and invest in my business. Thanks!", type='TextMessage'), TextMessage(id='7bcc0c96-97d9-4ed7-b7c8-e17993c0f407', source='ClarityAgent', models_usage=RequestUsage(prompt_tokens=79, completion_tokens=18), metadata={}, created_at=datetime.datetime(2026, 1, 26, 18, 11, 22, 135564, tzinfo=datetime.timezone.utc), content="Hi! I'm bored. Please buy me a coffee and invest in my business. Thanks!", type='TextMessage'), TextMessage(id='1f8ba2b0-63d9-4161-9b20-441fe803f0aa', source='ToneAgent', models_usage=RequestUsage(prompt_tokens=125, completion_tokens=106), metadata={}, created_at=datetime.datetime(2026, 1, 26, 18, 11, 26, 623833, tzinfo=datetime.timezone.utc), content='Subject: A Little Support Goes a Long Way!\n\nHi there,\n\nI hope this message finds you well! I wanted to reach out because I find myself in a bit of a creative lull. I would truly appreciate your support by grabbing a coffee together—perhaps we can brainstorm some exciting ideas for my business.\n\nYour investment would mean the world to me and could make a significant difference in taking my vision to the next level.\n\nThank you for considering this! Looking forward to hearing from you.\n\nWarm regards,  \n[Your Name]  ', type='TextMessage'), TextMessage(id='e8b5c5e5-b783-4964-987e-6c7ed4bc5959', source='PersuasionAgent', models_usage=RequestUsage(prompt_tokens=216, completion_tokens=159), metadata={}, created_at=datetime.datetime(2026, 1, 26, 18, 11, 31, 172341, tzinfo=datetime.timezone.utc), content="Subject: Let's Brew Something Amazing Together!\n\nHi [Recipient's Name],\n\nI hope this message finds you thriving! I’m reaching out to invite you to join me for a coffee—and in doing so, I’d love to share my vision for my business and discuss how your support can elevate it to new heights!\n\nImagine what we could accomplish together! With just a small investment, you could be a key player in transforming my ideas into reality. Your insights and support could provide the catalyst I need to break through this creative lull and create something extraordinary.\n\nAre you available to meet this week? I can’t wait to explore how we can collaborate and bring our ideas to life!\n\nThank you for considering this opportunity. Let’s connect soon!\n\nBest,  \n[Your Name]  \n[Your Contact Information]", type='TextMessage'), TextMessage(id='91f14aff-aafa-433f-b057-d8e852862693', source='SynthesizerAgent', models_usage=RequestUsage(prompt_tokens=421, completion_tokens=172), metadata={}, created_at=datetime.datetime(2026, 1, 26, 18, 11, 38, 830616, tzinfo=datetime.timezone.utc), content="Subject: Let’s Brew Something Amazing Together!\n\nHi [Recipient's Name],\n\nI hope this message finds you thriving! I'm reaching out with a proposal that combines inspiration and collaboration. I would love to invite you for a coffee, where I can share my vision for my business and explore how your support could elevate it to new heights.\n\nWith just a small investment, you could be an integral part of bringing my ideas to life. Your insights and encouragement would be invaluable, especially as I navigate through this creative lull. Together, we can brainstorm innovative strategies that could transform my business.\n\nAre you available to meet this week? I’m excited about the prospect of collaborating and would appreciate the opportunity to discuss this with you.\n\nThank you for considering this opportunity. I look forward to hearing from you soon!\n\nBest regards,  \n[Your Name]  \n[Your Contact Information]", type='TextMessage'), TextMessage(id='85476d81-14b3-47e4-8a92-f12952f1025c', source='CriticAgent', models_usage=RequestUsage(prompt_tokens=653, completion_tokens=10), metadata={}, created_at=datetime.datetime(2026, 1, 26, 18, 11,  ...
