# %%
from langgraph.graph import StateGraph, START, END
from langgraph.types import Command
from langgraph.graph.message import MessagesState
from langgraph.prebuilt import ToolNode, tools_condition
from langchain_core.tools import tool
from langchain.chat_models import init_chat_model

# %%
class AgentsState(MessagesState):
    current_agent: str
    transfered_by: str

    
llm = init_chat_model("openai:gpt-4o")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[14], line 6
#       2     current_agent: str
#       3     transfered_by: str
# ----> 6 llm = init_chat_model("openai:gpt-4o")
#
# File ~/projects/AiAgents/Multi-Agent-Architectures/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:324, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     316     warnings.warn(
#     317         f"{config_prefix=} has been set but no fields are configurable. Set "
#     318         f"`configurable_fields=(...)` to specify the model params that are "
#     319         f"configurable.",
#     320         stacklevel=2,
#     321     )
#     323 if not configurable_fields:
# --> 324     return _init_chat_model_helper(
#     325         cast(str, model),
#     326         model_provider=model_provider,
#     327         **kwargs,
#     328     )
#     329 if model:
#     330     kwargs["model"] = model
#
# File ~/projects/AiAgents/Multi-Agent-Architectures/.venv/lib/python3.13/site-packages/langchain/chat_models/base.py:351, in _init_chat_model_helper(model, model_provider, **kwargs)
#     348     _check_pkg("langchain_openai")
#     349     from langchain_openai import ChatOpenAI
# --> 351     return ChatOpenAI(model=model, **kwargs)
#     352 if model_provider == "anthropic":
#     353     _check_pkg("langchain_anthropic")
#
# File ~/projects/AiAgents/Multi-Agent-Architectures/.venv/lib/python3.13/site-packages/langchain_core/load/serializable.py:115, in Serializable.__init__(self, *args, **kwargs)
#     113 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     114     """"""  # noqa: D419  # Intentional blank docstring
# --> 115     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File ~/projects/AiAgents/Multi-Agent-Architectures/.venv/lib/python3.13/site-packages/langchain_openai/chat_models/base.py:825, in BaseChatOpenAI.validate_environment(self)
#     818         self.http_client = httpx.Client(
#     819             proxy=self.openai_proxy, verify=global_ssl_context
#     820         )
#     821     sync_specific = {
#     822         "http_client": self.http_client
#     823         or _get_default_httpx_client(self.openai_api_base, self.request_timeout)
#     824     }
# --> 825     self.root_client = openai.OpenAI(**client_params, **sync_specific)  # type: ignore[arg-type]
#     826     self.client = self.root_client.chat.completions
#     827 if not self.async_client:
#
# File ~/projects/AiAgents/Multi-Agent-Architectures/.venv/lib/python3.13/site-packages/openai/_client.py:139, in OpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     137     api_key = os.environ.get("OPENAI_API_KEY")
#     138 if api_key is None:
# --> 139     raise OpenAIError(
#     140         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     141     )
#     142 if callable(api_key):
#     143     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
